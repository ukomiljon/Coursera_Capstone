# %% [markdown]
# <a href="https://colab.research.google.com/github/ukomiljon/Coursera_Capstone/blob/master/Capstone_Project_Notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Capstone Project Notebook 1

# %%
import pandas as pd
import numpy as np

print("Hello Capstone Project Course!")
