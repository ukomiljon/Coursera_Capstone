# %% [markdown]
# <a href="https://colab.research.google.com/github/ukomiljon/Coursera_Capstone/blob/master/Capstone_Project_The_Battle_of_Neighborhoods_(Week_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **<H1>The Battle of Neighborhoods (Week 1)</H1>**

# %% [markdown]
# **<h2>Business Proposal / Introduction</h2>**

# %% [markdown]
# **Introduction:**

# %% [markdown]
# The objective of this Project is to find best solution for society, in order to make better decision around neighborhoods in Scarborough, Toranto.
#
# When people move across regions in Canada, they have to do find answer how is the safety, cost of life, level of pollution and how far distance of schools, entertainment places. However, it is hard to define all these aspects. On this project it is provided the solution by analysing wide features such as housing price, crime rate, climate conditions, water resources and facilities. It helps to people to get more clear information of region before moving.

# %% [markdown]
# **Business Problem**

# %% [markdown]
# The major purpose of this project, is to suggest a better neighborhood in a new city for the person who are shiffting there. Social presence in society in terms of like minded people. Connectivity to the airport, bus stand, city center, markets and other daily needs things nearby.
#
#
# 1.   Find each neighborhood along with the top 5 most common venues
# 2.   Find the top 10 venues for each neighborhood.
# 3.   Examine Clusters

# %% [markdown]
# **Methodology**

# %% [markdown]
# I was used Foursquare clustering machine learning algorithms

# %% [markdown]
# **Technology**

# %% [markdown]
# RestAPI: to get data
#
# Pandas: For creating and manipulating dataframes.
#
# Folium: Python visualization library would be used to visualize the neighborhoods cluster distribution of using interactive leaflet map.
#
# Scikit Learn: For importing k-means clustering.
#
# JSON: Library to handle JSON files.
#
# XML: To separate data from presentation and XML stores data in plain text format.
#
# Geocoder: To retrieve Location Data.
#
# Beautiful Soup and Requests: To scrap and library to handle http requests.
#
# Matplotlib: Python Plotting Module.

# %% [markdown]
# **<h2>Data Description**

# %% [markdown]
# 1.   "Postal Code", "Borough","Neighborhood" data is from wiki data https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# 2.   Geospatial data ( latitude and longitude) is in http://cocl.us/Geospatial_data
# 3.   Rest of data such as facilities, publica places and airoport is  from Foursquare
